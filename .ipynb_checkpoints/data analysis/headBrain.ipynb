# %%
import sys 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import scipy 
import sklearn as sk

# %%
plt.pyplot.rcParams['figure.figsize']=(20,10)

data=pd.read_csv('C:/Users/Operator/Desktop/CODING/Python/.ipynb_checkpoints/DataHouse/headbrain/headbrain.csv')
data.shape
data
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# ..      ...        ...              ...                  ...
# 232       2          2             3214                 1110
# 233       2          2             3394                 1215
# 234       2          2             3233                 1104
# 235       2          2             3352                 1170
# 236       2          2             3391                 1120
#
# [237 rows x 4 columns]

# %%
#Collecting X and Y
X= data['Head Size(cm^3)'].values
Y=data['Brain Weight(grams)'].values

# %%
mean_x=np.mean(X)
mean_y=np.mean(Y)

#TOTAL NUMBER OF VALUES
n = len(X)


#using the forrmula to calculate b1 and b0

numer=0
denom=0

for i in range(n):
    numer+=(X[i]-mean_x)*(Y[i] - mean_y) #finding numerator of equation 2
    denom+=(X[i]-mean_x)**2

b1=numer/denom
b0=mean_y-(b1*mean_x)

print(b1, b0)
# Out:
# 0.26342933948939945 325.57342104944223

# %%
sns.scatterplot(data=data)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
max_x= np.max(X)+100
min_x = np.min(X)-100

x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

plt.plot(x, y, color="blue", label='Regression line')  # Use plt.plot() directly
plt.scatter(X, Y, c='red', label="scatter plot")
plt.legend()
plt.show()  # To display the plot

# %%
ss_t= 0
ss_r=0


for i in range(n):
 y_pred=b0+b1*X[i]
 ss_t+=(Y[i]-mean_y)**2
 ss_r+=(Y[i]-y_pred)**2

r2=1-(ss_r/ss_t)
print(r2)
# Out:
# [0.63931172]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

X=X.reshape((n,1))

reg=LinearRegression()

reg=reg.fit(X,Y)

Y_pred=reg.predict(X)

r2_score= reg.score(X,Y)
print("R-Squared: ", r2_score )
# Out:
# R-Squared:  0.639311719957
